# %%
import pandas as pd

# %%
technical_skills = [
    'Python', 'R', 'SQL', 'Java', 'Scala', 'C++', 'C#', 'JavaScript', 'Tableau', 'Excel',
    'Hadoop', 'Spark', 'Kafka', 'TensorFlow', 'Keras', 'PyTorch', 'Machine Learning',
    'Deep Learning', 'NLP', 'Statistics', 'Data Mining', 'Data Visualization', 'Big Data',
    'AWS', 'Azure', 'GCP', 'Docker', 'Kubernetes', 'Git', 'Linux', 'APIs', 'SAS',
    'SPSS', 'Matlab', 'Power BI', 'Jupyter', 'Pandas', 'NumPy', 'Scikit-learn'
]

# Creating a counter for technical skills
technical_skills_counter = Counter()

for skills in data['skills_list']:
    for skill in skills:
        for tech_skill in technical_skills:
            if tech_skill.lower() in skill.lower():
                technical_skills_counter[tech_skill] += 1

# Getting the most common technical skills
most_common_technical_skills = technical_skills_counter.most_common(10)
most_common_technical_skills

# %%
# Creating a counter for technical skills for Research Scientists
technical_skills_counter_research_scientist = Counter()

for skills in technical_skills['skills_list']:
    for skill in skills:
        for tech_skill in technical_skills:
            if tech_skill.lower() in skill.lower():
                technical_skills_counter_research_scientist[tech_skill] += 1

# Getting the most common technical skills for Research Scientists
most_common_technical_skills_research_scientist = technical_skills_counter_research_scientist.most_common(10)
most_common_technical_skills_research_scientist
